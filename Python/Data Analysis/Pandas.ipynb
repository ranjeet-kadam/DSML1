# %%
! pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
## Series --> It is one dimensional array like an object that hold any datatype.

data = [1,2,3,4,5]

series = pd.Series(data)
print("Series is :\n",series)
# Out:
# Series is :
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
### Create A Series for Dictionary

data = { 'a':1,'b':2,'c':3,'d':4}
series = pd.Series(data)
print(series)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
### Create a Dataframe by Dictionary

data ={
    'Name':['Andy','Marnus','Pluto'],
    'City': ['New York','Southampton','Budapest'],
    'Age':[23,45,56]
}

df =pd.DataFrame(data)
df
#print(type(df))
# Out:
#      Name         City  Age
# 0    Andy     New York   23
# 1  Marnus  Southampton   45
# 2   Pluto     Budapest   56

# %%
### Create a Dataframe by using dictionary

data =[
    ['Alice',34,'Paris'],['Mark',28,'Edinburg'],['Nans',24,'London']
]

df = pd.DataFrame(data,columns=['Name','Age','City'])
df
# Out:
#     Name  Age      City
# 0  Alice   34     Paris
# 1   Mark   28  Edinburg
# 2   Nans   24    London

# %%
## Read file from different sources

df= pd.read_csv("sales_data (1).csv")
df
# Out:
#    Order ID        Date Customer Name     Product     Category  Quantity  \
# 0      1001  2023-01-01         Alice      Laptop  Electronics         1
# 1      1002  2023-01-03           Bob  Smartphone  Electronics         2
# 2      1003  2023-01-05       Charlie      Tablet  Electronics         1
# 3      1004  2023-01-07         David     Monitor  Electronics         2
# 4      1005  2023-01-10           Eva     Printer  Electronics         1
#
#    Unit Price  Total Sales
# 0        1200         1200
# 1         800         1600
# 2         300          300
# 3         200          400
# 4         150          150

# %%
### Accessing values from the dataset in Pandas
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Salary': [50000, 60000, 70000]
}

df = pd.DataFrame(data)
df
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000

# %%
### Accessing columens 

df['Name']
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object

# %%
df[['Name','Salary']]
# Out:
#       Name  Salary
# 0    Alice   50000
# 1      Bob   60000
# 2  Charlie   70000

# %%
df.loc[0]
#df.iloc[0]
# Out:
# Name      Alice
# Age          25
# Salary    50000
# Name: 0, dtype: object

# %%
### Accessing specific elements from dataset

print(df.at[1,'Age'])
# Out:
# 30

# %%
df.at[1,'Age'] = 29
df
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   29   60000
# 2  Charlie   33   70000

# %%
### Accessing specific elements by using iat

df.iat[2,1] = 33
print(df.iat[2,1])
# Out:
# 33

# %%
df
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   33   70000

# %%
### Add a column in Dataframe

df['City']=['Florida','New York','Texas']
df
# Out:
#       Name  Age  Salary      City
# 0    Alice   25   50000   Florida
# 1      Bob   30   60000  New York
# 2  Charlie   35   70000     Texas

# %%
### Remove Column in Dataframe

df.drop('City',axis=1,inplace=True)
df
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000

# %%
df
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000

# %%
df.describe()
# Out:
#         Age   Salary
# count   3.0      3.0
# mean   30.0  60000.0
# std     5.0  10000.0
# min    25.0  50000.0
# 25%    27.5  55000.0
# 50%    30.0  60000.0
# 75%    32.5  65000.0
# max    35.0  70000.0

# %%
df
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000

# %%
df_new=df.iat[2,1] = 34
df
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   34   70000

# %%
df.at[2,'Age']
# Out:
# np.int64(34)

# %%
df.loc[0:3,'Age']
# Out:
# 0    25
# 1    30
# 2    34
# Name: Age, dtype: int64

# %%
df.iloc[2:,[1]]
# Out:
#    Age
# 2   34

# %%
df
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   34   70000

# %%
df_new =df.copy()
new_data = {
    'Name': 'Shreya',
    'Age': 25,
    'Salary': 70000
}
df_new =pd.concat([df_new, pd.DataFrame([new_data])], ignore_index=True)
df_new
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   34   70000
# 3   Shreya   25   70000

# %%
df_merged = pd.merge(df,df_new,how ='outer',on= None)
df_merged
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   34   70000
# 3   Shreya   25   70000

# %%
import pandas as pd

data = {
    'Department': ['IT', 'HR', 'IT', 'HR', 'Finance', 'IT'],
    'Employee': ['A', 'B', 'C', 'D', 'E', 'F'],
    'Salary': [50000, 40000, 60000, 45000, 70000, 55000]
}

df = pd.DataFrame(data)
print(df)
# Out:
#   Department Employee  Salary
# 0         IT        A   50000
# 1         HR        B   40000
# 2         IT        C   60000
# 3         HR        D   45000
# 4    Finance        E   70000
# 5         IT        F   55000

# %%
df.groupby('Department')['Salary'].mean()
# Out:
# Department
# Finance    70000.0
# HR         42500.0
# IT         55000.0
# Name: Salary, dtype: float64

# %%
df.groupby('Department')['Salary'].agg(['mean', 'sum', 'count'])
# Out:
#                mean     sum  count
# Department
# Finance     70000.0   70000      1
# HR          42500.0   85000      2
# IT          55000.0  165000      3

# %%
df.groupby('Department')['Salary'].apply(lambda x: x.max() - x.min())
# Out:
# Department
# Finance        0
# HR          5000
# IT         10000
# Name: Salary, dtype: int64

# %%
import pandas as pd

df1 = pd.DataFrame({
    'EmpID': [1, 2, 3],
    'Name': ['A', 'B', 'C']
})

df2 = pd.DataFrame({
    'EmpID': [1, 2, 4],
    'Salary': [50000, 60000, 70000]
})

# %%
pd.merge(df1, df2, on='EmpID', how='inner')
# Out:
#    EmpID Name  Salary
# 0      1    A   50000
# 1      2    B   60000

# %%
pd.merge(df1, df2, on='EmpID', how='left')
# Out:
#    EmpID Name   Salary
# 0      1    A  50000.0
# 1      2    B  60000.0
# 2      3    C      NaN

# %%
pd.merge(df1, df2, on='EmpID', how='right')
# Out:
#    EmpID Name  Salary
# 0      1    A   50000
# 1      2    B   60000
# 2      4  NaN   70000

# %%
pd.merge(df1, df2, on='EmpID', how='outer')
# Out:
#    EmpID Name   Salary
# 0      1    A  50000.0
# 1      2    B  60000.0
# 2      3    C      NaN
# 3      4  NaN  70000.0

# %%
df_join = df1.join(df2.set_index('EmpID'),on = 'EmpID',how = 'inner')
df_join
# Out:
#    EmpID Name  Salary
# 0      1    A   50000
# 1      2    B   60000

# %%
import pandas as pd

df = pd.DataFrame({
    'Region': ['North', 'South', 'West'],
    'Jan': [10000, 15000, 12000],
    'Feb': [11000, 14000, 13000],
    'Mar': [12000, 16000, 12500]
})

print(df)
# Out:
#   Region    Jan    Feb    Mar
# 0  North  10000  11000  12000
# 1  South  15000  14000  16000
# 2   West  12000  13000  12500

# %%
df_melt = pd.melt(
    df,
    id_vars=['Region'],
    var_name='Month',
    value_name='Sales'
)

print(df_melt)
# Out:
#   Region Month  Sales
# 0  North   Jan  10000
# 1  South   Jan  15000
# 2   West   Jan  12000
# 3  North   Feb  11000
# 4  South   Feb  14000
# 5   West   Feb  13000
# 6  North   Mar  12000
# 7  South   Mar  16000
# 8   West   Mar  12500

# %%
df_melt.groupby('Month')['Sales'].sum()
# Out:
# Month
# Feb    38000
# Jan    37000
# Mar    40500
# Name: Sales, dtype: int64

# %%
df_melt.groupby('Region')['Sales'].mean()
# Out:
# Region
# North    11000.0
# South    15000.0
# West     12500.0
# Name: Sales, dtype: float64

# %%
import pandas as pd

df_melt = pd.DataFrame({
    'Region': ['North', 'North', 'North', 'South', 'South', 'South', 'West', 'West', 'West'],
    'Month': ['Jan', 'Feb', 'Mar'] * 3,
    'Sales': [10000, 11000, 12000, 15000, 14000, 16000, 12000, 13000, 12500]
})

print(df_melt)
# Out:
#   Region Month  Sales
# 0  North   Jan  10000
# 1  North   Feb  11000
# 2  North   Mar  12000
# 3  South   Jan  15000
# 4  South   Feb  14000
# 5  South   Mar  16000
# 6   West   Jan  12000
# 7   West   Feb  13000
# 8   West   Mar  12500

# %%
df_pivot = df_melt.pivot(index='Region', columns='Month', values='Sales')

print(df_pivot)
# Out:
# Month     Feb    Jan    Mar
# Region
# North   11000  10000  12000
# South   14000  15000  16000
# West    13000  12000  12500

# %%
def is_prime(number):
    if number < 1 :
        return False
    for i in range(2, int(number**0.5 )+1):
        if number % i==0:
            return False
        return True

number =int(input("Enter the Number :"))
if is_prime(number):
    print(f"{number} is a prime number") 
else :
    print(f"{number} is not a prime number")
# Out:
# 97 is a prime number
